# %%
import numpy as np

# %%
class Perceptron(object):

  def __init__(self , number_of_inputs , thres = 100 , lr = 0.01):
    self.thres = thres 
    self.lr = lr  
    self.weights = np.zeros(number_of_inputs)

  def predict(self , inputs):

    summation = np.dot(inputs , self.weights[1:]) + self.weights[0]

    if summation > 0 :
      activation = 1
    else :
      activation = 0

    return activation

  def train(self , training_inputs , labels):

    for _ in range(self.thres) :
# Out:
#   File "<ipython-input-10-1510a3ce297f>", line 24
#
#     ^
# SyntaxError: unexpected EOF while parsing
